# %% [markdown]
# Zadanie1

# %% [markdown]
# INITIAL

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("ActorsData").getOrCreate()
from pyspark.sql.functions import col, lit, explode, regexp_replace, regexp_extract, isnull, ifnull, split, array_contains, expr
from pyspark.sql.functions import desc, count, avg

# %%
dataframe = spark.read.csv("actors.csv", header=True, inferSchema=True)
dataframe.show()
# Out:
# +-------------+--------+------------+---------------+----------+--------------------+
# |imdb_title_id|ordering|imdb_name_id|       category|       job|          characters|
# +-------------+--------+------------+---------------+----------+--------------------+
# |    tt0000009|       1|   nm0063086|        actress|      NULL|[Miss Geraldine H...|
# |    tt0000009|       2|   nm0183823|          actor|      NULL|      [Mr. Hamilton]|
# |    tt0000009|       3|   nm1309758|          actor|      NULL|[Chauncey Depew -...|
# |    tt0000009|       4|   nm0085156|       director|      NULL|                NULL|
# |    tt0000574|       1|   nm0846887|        actress|      NULL|        [Kate Kelly]|
# |    tt0000574|       2|   nm0846894|          actor|      NULL|     [School Master]|
# |    tt0000574|       3|   nm3002376|          actor|      NULL|        [Steve Hart]|
# |    tt0000574|       4|   nm0170118|        actress|      NULL|                NULL|
# |    tt0000574|       5|   nm0846879|       director|      NULL|                NULL|
# |    tt0000574|       6|   nm0317210|       producer|  producer|                NULL|
# |    tt0000574|       7|   nm0425854|       producer|  producer|                NULL|
# |    tt0000574|       8|   nm0846911|       producer|  producer|                NULL|
# |    tt0000574|       9|   nm2421834|       composer|      NULL|                NULL|
# |    tt0000574|      10|   nm0675239|cinematographer|      NULL|                NULL|
# |    tt0001892|       1|   nm0003425|        actress|      NULL|            [Stella]|
# |    tt0001892|       2|   nm0699637|          actor|      NULL|[Grev Johan Waldb...|
# |    tt0001892|       3|   nm0375839|          actor|      NULL|[Hofjuveler A. Hi...|
# |    tt0001892|       4|   nm0016799|          actor|      NULL|                NULL|
# |    tt0001892|       5|   nm0300487|       director|      NULL|                NULL|
# |    tt0001892|       6|   nm2131092|         writer|screenplay|                NULL|
# +-------------+--------+------------+---------------+----------+--------------------+
# only showing top 20 rows

# %% [markdown]
# A)

# %%
df_filled = dataframe.fillna({"job": 'Unknown'})

df_nulls = dataframe.withColumn("is_character_null", isnull(col("characters")))

df_ifnull = dataframe.withColumn("job_fixed", ifnull(col("job"), lit("Unknown"))) 

df_nullIf = dataframe.withColumn("job_filtered", expr("nullIf(job, 'Unknown')")) 

df_cleaned = dataframe.withColumn("characters_cleaned", regexp_replace(col("characters"), "[^a-zA-Z ]", ""))

df_extracted = dataframe.withColumn("category_first_word", regexp_extract(col("category"), r"(\w+)", 1))  

df_fixed = dataframe.withColumn("characters_array", split(col("characters"), ", "))
df_exploded = df_fixed.withColumn("character", explode(col("characters_array")))

df_fixed2 = dataframe.withColumn("characters_array", split(col("characters"), ", "))
df_array_check = df_fixed.withColumn("contains_steve", array_contains(col("characters_array"), "Steve Hart"))

df_dropped = dataframe.drop("job")

df_filled.show()
df_nulls.show()
df_ifnull.show()
df_nullIf.show()
df_cleaned.show()
df_extracted.show()
df_exploded.show()
df_array_check.show()
df_dropped.show()
# Out:
# +-------------+--------+------------+---------------+----------+--------------------+
# |imdb_title_id|ordering|imdb_name_id|       category|       job|          characters|
# +-------------+--------+------------+---------------+----------+--------------------+
# |    tt0000009|       1|   nm0063086|        actress|   Unknown|[Miss Geraldine H...|
# |    tt0000009|       2|   nm0183823|          actor|   Unknown|      [Mr. Hamilton]|
# |    tt0000009|       3|   nm1309758|          actor|   Unknown|[Chauncey Depew -...|
# |    tt0000009|       4|   nm0085156|       director|   Unknown|                NULL|
# |    tt0000574|       1|   nm0846887|        actress|   Unknown|        [Kate Kelly]|
# |    tt0000574|       2|   nm0846894|          actor|   Unknown|     [School Master]|
# |    tt0000574|       3|   nm3002376|          actor|   Unknown|        [Steve Hart]|
# |    tt0000574|       4|   nm0170118|        actress|   Unknown|                NULL|
# |    tt0000574|       5|   nm0846879|       director|   Unknown|                NULL|
# |    tt0000574|       6|   nm0317210|       producer|  producer|                NULL|
# |    tt0000574|       7|   nm0425854|       producer|  producer|                NULL|
# |    tt0000574|       8|   nm0846911|       producer|  producer|                NULL|
# |    tt0000574|       9|   nm2421834|       composer|   Unknown|                NULL|
# |    tt0000574|      10|   nm0675239|cinematographer|   Unknown|                NULL|
# |    tt0001892|       1|   nm0003425|        actress|   Unknown|            [Stella]|
# |    tt0001892|       2|   nm0699637|          actor|   Unknown|[Grev Johan Waldb...|
# |    tt0001892|       3|   nm0375839|          actor|   Unknown|[Hofjuveler A. Hi...|
# |    tt0001892|       4|   nm0016799|          actor|   Unknown|                NULL|
# |    tt0001892|       5|   nm0300487|       director|   Unknown|                NULL|
# |    tt0001892|       6|   nm2131092|         writer|screenplay|                NULL|
# +-------------+--------+------------+---------------+----------+--------------------+
# only showing top 20 rows
#
# +-------------+--------+------------+---------------+----------+--------------------+-----------------+
# |imdb_title_id|ordering|imdb_name_id|       category|       job|          characters|is_character_null|
# +-------------+--------+------------+---------------+----------+--------------------+-----------------+
# |    tt0000009|       1|   nm0063086|        actress|      NULL|[Miss Geraldine H...|            false|
# |    tt0000009|       2|   nm0183823|          actor|      NULL|      [Mr. Hamilton]|            false|
# |    tt0000009|       3|   nm1309758|          actor|      NULL|[Chauncey Depew -...|            false|
# |    tt0000009|       4|   nm0085156|       director|      NULL|                NULL|             true|
# |    tt0000574|       1|   nm0846887|        actress|      NULL|        [Kate Kelly]|            false|
# |    tt0000574|       2|   nm0846894|          actor|      NULL|     [School Master]|            false|
# |    tt0000574|       3|   nm3002376|          actor|      NULL|        [Steve Hart]|            false|
# |    tt0000574|       4|   nm0170118|        actress|      NULL|                NULL|             true|
# |    tt0000574|       5|   nm0846879|       director|      NULL|                NULL|             true|
# |    tt0000574|       6|   nm0317210|       producer|  producer|                NULL|             true|
# |    tt0000574|       7|   nm0425854|       producer|  producer|                NULL|             true|
# |    tt0000574|       8|   nm0846911|       producer|  producer|                NULL|             true|
# |    tt0000574|       9|   nm2421834|       composer|      NULL|                NULL|             true|
# |    tt0000574|      10|   nm0675239|cinematographer|      NULL|                NULL|             true|
# |    tt0001892|       1|   nm0003425|        actress|      NULL|            [Stella]|            false|
# |    tt0001892|       2|   nm0699637|          actor|      NULL|[Grev Johan Waldb...|            false|
# |    tt0001892|       3|   nm0375839|          actor|      NULL|[Hofjuveler A. Hi...|            false|
# |    tt0001892|       4|   nm0016799|          actor|      NULL|                NULL|             true|
# |    tt0001892|       5|   nm0300487|       director|      NULL|                NULL|             true|
# |    tt0001892|       6|   nm2131092|         writer|screenplay|                NULL|             true|
# +-------------+--------+------------+---------------+----------+--------------------+-----------------+
# only showing top 20 rows
#
# +-------------+--------+------------+---------------+----------+--------------------+----------+
# |imdb_title_id|ordering|imdb_name_id|       category|       job|          characters| job_fixed|
# +-------------+--------+------------+---------------+----------+--------------------+----------+
# |    tt0000009|       1|   nm0063086|        actress|      NULL|[Miss Geraldine H...|   Unknown|
# |    tt0000009|       2|   nm0183823|          actor|      NULL|      [Mr. Hamilton]|   Unknown|
# |    tt0000009|       3|   nm1309758|          actor|      NULL|[Chauncey Depew -...|   Unknown|
# |    tt0000009|       4|   nm0085156|       director|      NULL|                NULL|   Unknown|
# |    tt0000574|       1|   nm0846887|        actress|      NULL|        [Kate Kelly]|   Unknown|
# |    tt0000574|       2|   nm0846894|          actor|      NULL|     [School Master]|   Unknown|
# |    tt0000574|       3|   nm3002376|          actor|      NULL|        [Steve Hart]|   Unknown|
# |    tt0000574|       4|   nm0170118|        actress|      NULL|                NULL|   Unknown|
# |    tt0000574|       5|   nm0846879|       director|      NULL|                NULL|   Unknown|
# |    tt0000574|       6|   nm0317210|       producer|  producer|                NULL|  producer|
# |    tt0000574|       7|   nm0425854|       producer|  producer|                NULL|  producer|
# |    tt0000574|       8|   nm0846911|       producer|  producer|                NULL|  producer|
# |    tt0000574|       9|   nm2421834|       composer|      NULL|                NULL|   Unknown|
# |    tt0000574|      10|   nm0675239|cinematographer|      NULL|                NULL|   Unknown|
# |    tt0001892|       1|   nm0003425|        actress|      NULL|            [Stella]|   Unknown|
# |    tt0001892|       2|   nm0699637|          actor|      NULL|[Grev Johan Waldb...|   Unknown|
# |    tt0001892|       3|   nm0375839|          actor|      NULL|[Hofjuveler A. Hi...|   Unknown|
# |    tt0001892|       4|   nm0016799|          actor|      NULL|                NULL|   Unknown|
# |    tt0001892|       5|   nm0300487|       director|      NULL|                NULL|   Unknown|
# |    tt0001892|       6|   nm2131092|         writer|screenplay|                NULL|screenplay|
# +-------------+--------+------------+---------------+----------+--------------------+----------+
# only showing top 20 rows
#
# +-------------+--------+------------+---------------+----------+--------------------+------------+
# |imdb_title_id|ordering|imdb_name_id|       category|       job|          characters|job_filtered|
# +-------------+--------+------------+---------------+----------+--------------------+------------+
# |    tt0000009|       1|   nm0063086|        actress|      NULL|[Miss Geraldine H...|        NULL|
# |    tt0000009|       2|   nm0183823|          actor|      NULL|      [Mr. Hamilton]|        NULL|
# |    tt0000009|       3|   nm1309758|          actor|      NULL|[Chauncey Depew -...|        NULL|
# |    tt0000009|       4|   nm0085156|       director|      NULL|                NULL|        NULL|
# |    tt0000574|       1|   nm0846887|        actress|      NULL|        [Kate Kelly]|        NULL|
# |    tt0000574|       2|   nm0846894|          actor|      NULL|     [School Master]|        NULL|
# |    tt0000574|       3|   nm3002376|          actor|      NULL|        [Steve Hart]|        NULL|
# |    tt0000574|       4|   nm0170118|        actress|      NULL|                NULL|        NULL|
# |    tt0000574|       5|   nm0846879|       director|      NULL|                NULL|        NULL|
# |    tt0000574|       6|   nm0317210|       producer|  producer|                NULL|    producer|
# |    tt0000574|       7|   nm0425854|       producer|  producer|                NULL|    producer|
# |    tt0000574|       8|   nm0846911|       producer|  producer|                NULL|    producer|
# |    tt0000574|       9|   nm2421834|       composer|      NULL|                NULL|        NULL|
# |    tt0000574|      10|   nm0675239|cinematographer|      NULL|                NULL|        NULL|
# |    tt0001892|       1|   nm0003425|        actress|      NULL|            [Stella]|        NULL|
# |    tt0001892|       2|   nm0699637|          actor|      NULL|[Grev Johan Waldb...|        NULL|
# |    tt0001892|       3|   nm0375839|          actor|      NULL|[Hofjuveler A. Hi...|        NULL|
# |    tt0001892|       4|   nm0016799|          actor|      NULL|                NULL|        NULL|
# |    tt0001892|       5|   nm0300487|       director|      NULL|                NULL|        NULL|
# |    tt0001892|       6|   nm2131092|         writer|screenplay|                NULL|  screenplay|
# +-------------+--------+------------+---------------+----------+--------------------+------------+
# only showing top 20 rows
#
# +-------------+--------+------------+---------------+----------+--------------------+--------------------+
# |imdb_title_id|ordering|imdb_name_id|       category|       job|          characters|  characters_cleaned|
# +-------------+--------+------------+---------------+----------+--------------------+--------------------+
# |    tt0000009|       1|   nm0063086|        actress|      NULL|[Miss Geraldine H...|Miss Geraldine Ho...|
# |    tt0000009|       2|   nm0183823|          actor|      NULL|      [Mr. Hamilton]|         Mr Hamilton|
# |    tt0000009|       3|   nm1309758|          actor|      NULL|[Chauncey Depew -...|Chauncey Depew  t...|
# |    tt0000009|       4|   nm0085156|       director|      NULL|                NULL|                NULL|
# |    tt0000574|       1|   nm0846887|        actress|      NULL|        [Kate Kelly]|          Kate Kelly|
# |    tt0000574|       2|   nm0846894|          actor|      NULL|     [School Master]|       School Master|
# |    tt0000574|       3|   nm3002376|          actor|      NULL|        [Steve Hart]|          Steve Hart|
# |    tt0000574|       4|   nm0170118|        actress|      NULL|                NULL|                NULL|
# |    tt0000574|       5|   nm0846879|       director|      NULL|                NULL|                NULL|
# |    tt0000574|       6|   nm0317210|       producer|  producer|                NULL|                NULL|
# |    tt0000574|       7|   nm0425854|       producer|  producer|                NULL|                NULL|
# |    tt0000574|       8|   nm0846911|       producer|  producer|                NULL|                NULL|
# |    tt0000574|       9|   nm2421834|       composer|      NULL|                NULL|                NULL|
# |    tt0000574|      10|   nm0675239|cinematographer|      NULL|                NULL|                NULL|
# |    tt0001892|       1|   nm0003425|        actress|      NULL|            [Stella]|              Stella|
# |    tt0001892|       2|   nm0699637|          actor|      NULL|[Grev Johan Waldb...| Grev Johan Waldberg|
# |    tt0001892|       3|   nm0375839|          actor|      NULL|[Hofjuveler A. Hi...| Hofjuveler A Hirsch|
# |    tt0001892|       4|   nm0016799|          actor|      NULL|                NULL|                NULL|
# |    tt0001892|       5|   nm0300487|       director|      NULL|                NULL|                NULL|
# |    tt0001892|       6|   nm2131092|         writer|screenplay|                NULL|                NULL|
# +-------------+--------+------------+---------------+----------+--------------------+--------------------+
# only showing top 20 rows
#
# +-------------+--------+------------+---------------+----------+--------------------+-------------------+
# |imdb_title_id|ordering|imdb_name_id|       category|       job|          characters|category_first_word|
# +-------------+--------+------------+---------------+----------+--------------------+-------------------+
# |    tt0000009|       1|   nm0063086|        actress|      NULL|[Miss Geraldine H...|            actress|
# |    tt0000009|       2|   nm0183823|          actor|      NULL|      [Mr. Hamilton]|              actor|
# |    tt0000009|       3|   nm1309758|          actor|      NULL|[Chauncey Depew -...|              actor|
# |    tt0000009|       4|   nm0085156|       director|      NULL|                NULL|           director|
# |    tt0000574|       1|   nm0846887|        actress|      NULL|        [Kate Kelly]|            actress|
# |    tt0000574|       2|   nm0846894|          actor|      NULL|     [School Master]|              actor|
# |    tt0000574|       3|   nm3002376|          actor|      NULL|        [Steve Hart]|              actor|
# |    tt0000574|       4|   nm0170118|        actress|      NULL|                NULL|            actress|
# |    tt0000574|       5|   nm0846879|       director|      NULL|                NULL|           director|
# |    tt0000574|       6|   nm0317210|       producer|  producer|                NULL|           producer|
# |    tt0000574|       7|   nm0425854|       producer|  producer|                NULL|           producer|
# |    tt0000574|       8|   nm0846911|       producer|  producer|                NULL|           producer|
# |    tt0000574|       9|   nm2421834|       composer|      NULL|                NULL|           composer|
# |    tt0000574|      10|   nm0675239|cinematographer|      NULL|                NULL|    cinematographer|
# |    tt0001892|       1|   nm0003425|        actress|      NULL|            [Stella]|            actress|
# |    tt0001892|       2|   nm0699637|          actor|      NULL|[Grev Johan Waldb...|              actor|
# |    tt0001892|       3|   nm0375839|          actor|      NULL|[Hofjuveler A. Hi...|              actor|
# |    tt0001892|       4|   nm0016799|          actor|      NULL|                NULL|              actor|
# |    tt0001892|       5|   nm0300487|       director|      NULL|                NULL|           director|
# |    tt0001892|       6|   nm2131092|         writer|screenplay|                NULL|             writer|
# +-------------+--------+------------+---------------+----------+--------------------+-------------------+
# only showing top 20 rows
#
# +-------------+--------+------------+--------+----+--------------------+--------------------+--------------------+
# |imdb_title_id|ordering|imdb_name_id|category| job|          characters|    characters_array|           character|
# +-------------+--------+------------+--------+----+--------------------+--------------------+--------------------+
# |    tt0000009|       1|   nm0063086| actress|NULL|[Miss Geraldine H...|[[Miss Geraldine ...|[Miss Geraldine H...|
# |    tt0000009|       2|   nm0183823|   actor|NULL|      [Mr. Hamilton]|    [[Mr. Hamilton]]|      [Mr. Hamilton]|
# |    tt0000009|       3|   nm1309758|   actor|NULL|[Chauncey Depew -...|[[Chauncey Depew ...|[Chauncey Depew -...|
# |    tt0000574|       1|   nm0846887| actress|NULL|        [Kate Kelly]|      [[Kate Kelly]]|        [Kate Kelly]|
# |    tt0000574|       2|   nm0846894|   actor|NULL|     [School Master]|   [[School Master]]|     [School Master]|
# |    tt0000574|       3|   nm3002376|   actor|NULL|        [Steve Hart]|      [[Steve Hart]]|        [Steve Hart]|
# |    tt0001892|       1|   nm0003425| actress|NULL|            [Stella]|          [[Stella]]|            [Stella]|
# |    tt0001892|       2|   nm0699637|   actor|NULL|[Grev Johan Waldb...|[[Grev Johan Wald...|[Grev Johan Waldb...|
# |    tt0001892|       3|   nm0375839|   actor|NULL|[Hofjuveler A. Hi...|[[Hofjuveler A. H...|[Hofjuveler A. Hi...|
# |    tt0002101|       1|   nm0306947| actress|NULL|[Cleopatra - Quee...|[[Cleopatra - Que...|[Cleopatra - Quee...|
# |    tt0002101|       2|   nm0801774| actress|NULL|[Iras - An Attend...|[[Iras - An Atten...|[Iras - An Attend...|
# |    tt0002101|       3|   nm0276160| actress|NULL|[Charmian - An At...|[[Charmian - An A...|[Charmian - An At...|
# |    tt0002101|       4|   nm0733482| actress|NULL|[Octavia - Wife o...|[[Octavia - Wife ...|[Octavia - Wife o...|
# |    tt0002101|       7|   nm0182557| actress|NULL|  [Nicola - a Child]|[[Nicola - a Child]]|  [Nicola - a Child]|
# |    tt0002101|       8|   nm1950505|   actor|NULL|[Antony - a Trium...|[[Antony - a Triu...|[Antony - a Trium...|
# |    tt0002101|       9|   nm0397513|   actor|NULL|[Pharon - a Greek...|[[Pharon - a Gree...|[Pharon - a Greek...|
# |    tt0002101|      10|   nm0906610|   actor|NULL|[Venditius - a Ro...|[[Venditius - a R...|[Venditius - a Ro...|
# |    tt0002130|       1|   nm0660139|   actor|NULL|   [Dante Alighieri]| [[Dante Alighieri]]|   [Dante Alighieri]|
# |    tt0002130|       2|   nm0685283|   actor|NULL|          [Virgilio]|        [[Virgilio]]|          [Virgilio]|
# |    tt0002130|       3|   nm0209738|   actor|NULL|[Farinata degli U...|[[Farinata degli ...|[Farinata degli U...|
# +-------------+--------+------------+--------+----+--------------------+--------------------+--------------------+
# only showing top 20 rows
#
# +-------------+--------+------------+---------------+----------+--------------------+--------------------+--------------+
# |imdb_title_id|ordering|imdb_name_id|       category|       job|          characters|    characters_array|contains_steve|
# +-------------+--------+------------+---------------+----------+--------------------+--------------------+--------------+
# |    tt0000009|       1|   nm0063086|        actress|      NULL|[Miss Geraldine H...|[[Miss Geraldine ...|         false|
# |    tt0000009|       2|   nm0183823|          actor|      NULL|      [Mr. Hamilton]|    [[Mr. Hamilton]]|         false|
# |    tt0000009|       3|   nm1309758|          actor|      NULL|[Chauncey Depew -...|[[Chauncey Depew ...|         false|
# |    tt0000009|       4|   nm0085156|       director|      NULL|                NULL|                NULL|          NULL|
# |    tt0000574|       1|   nm0846887|        actress|      NULL|        [Kate Kelly]|      [[Kate Kelly]]|         false|
# |    tt0000574|       2|   nm0846894|          actor|      NULL|     [School Master]|   [[School Master]]|         false|
# |    tt0000574|       3|   nm3002376|          actor|      NULL|        [Steve Hart]|      [[Steve Hart]]|         false|
# |    tt0000574|       4|   nm0170118|        actress|      NULL|                NULL|                NULL|          NULL|
# |    tt0000574|       5|   nm0846879|       director|      NULL|                NULL|                NULL|          NULL|
# |    tt0000574|       6|   nm0317210|       producer|  producer|                NULL|                NULL|          NULL|
# |    tt0000574|       7|   nm0425854|       producer|  producer|                NULL|                NULL|          NULL|
# |    tt0000574|       8|   nm0846911|       producer|  producer|                NULL|                NULL|          NULL|
# |    tt0000574|       9|   nm2421834|       composer|      NULL|                NULL|                NULL|          NULL|
# |    tt0000574|      10|   nm0675239|cinematographer|      NULL|                NULL|                NULL|          NULL|
# |    tt0001892|       1|   nm0003425|        actress|      NULL|            [Stella]|          [[Stella]]|         false|
# |    tt0001892|       2|   nm0699637|          actor|      NULL|[Grev Johan Waldb...|[[Grev Johan Wald...|         false|
# |    tt0001892|       3|   nm0375839|          actor|      NULL|[Hofjuveler A. Hi...|[[Hofjuveler A. H...|         false|
# |    tt0001892|       4|   nm0016799|          actor|      NULL|                NULL|                NULL|          NULL|
# |    tt0001892|       5|   nm0300487|       director|      NULL|                NULL|                NULL|          NULL|
# |    tt0001892|       6|   nm2131092|         writer|screenplay|                NULL|                NULL|          NULL|
# +-------------+--------+------------+---------------+----------+--------------------+--------------------+--------------+
# only showing top 20 rows
#
# +-------------+--------+------------+---------------+--------------------+
# |imdb_title_id|ordering|imdb_name_id|       category|          characters|
# +-------------+--------+------------+---------------+--------------------+
# |    tt0000009|       1|   nm0063086|        actress|[Miss Geraldine H...|
# |    tt0000009|       2|   nm0183823|          actor|      [Mr. Hamilton]|
# |    tt0000009|       3|   nm1309758|          actor|[Chauncey Depew -...|
# |    tt0000009|       4|   nm0085156|       director|                NULL|
# |    tt0000574|       1|   nm0846887|        actress|        [Kate Kelly]|
# |    tt0000574|       2|   nm0846894|          actor|     [School Master]|
# |    tt0000574|       3|   nm3002376|          actor|        [Steve Hart]|
# |    tt0000574|       4|   nm0170118|        actress|                NULL|
# |    tt0000574|       5|   nm0846879|       director|                NULL|
# |    tt0000574|       6|   nm0317210|       producer|                NULL|
# |    tt0000574|       7|   nm0425854|       producer|                NULL|
# |    tt0000574|       8|   nm0846911|       producer|                NULL|
# |    tt0000574|       9|   nm2421834|       composer|                NULL|
# |    tt0000574|      10|   nm0675239|cinematographer|                NULL|
# |    tt0001892|       1|   nm0003425|        actress|            [Stella]|
# |    tt0001892|       2|   nm0699637|          actor|[Grev Johan Waldb...|
# |    tt0001892|       3|   nm0375839|          actor|[Hofjuveler A. Hi...|
# |    tt0001892|       4|   nm0016799|          actor|                NULL|
# |    tt0001892|       5|   nm0300487|       director|                NULL|
# |    tt0001892|       6|   nm2131092|         writer|                NULL|
# +-------------+--------+------------+---------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# B)

# %% [markdown]
# UŻYCIE 3 FUNKCJI AGREGUJĄCYCH, KTÓRE UWAŻAM ZA CIEKAWE

# %%
# 1. Najczęstsza kategoria  
df_category_count = dataframe.groupBy("category").count().orderBy(desc("count"))  

# 2. Średnia liczba ról na film  
df_avg_roles = dataframe.groupBy("imdb_title_id").agg(count("imdb_name_id").alias("num_roles")).agg(avg("num_roles"))  

# 3. Liczba unikalnych aktorów  
df_unique_actors = dataframe.select(count("imdb_name_id").alias("unique_actors"))

df_category_count.show()
df_avg_roles.show()
df_unique_actors.show()
# Out:
# +-------------------+------+
# |           category| count|
# +-------------------+------+
# |              actor|222337|
# |            actress|133414|
# |             writer|122793|
# |           producer|101092|
# |           director| 88968|
# |           composer| 66861|
# |    cinematographer| 55423|
# |             editor| 33780|
# |production_designer|  9485|
# |               self|   909|
# |    archive_footage|   444|
# |      archive_sound|     7|
# +-------------------+------+
#
# +-----------------+
# |   avg(num_roles)|
# +-----------------+
# |9.732469015003261|
# +-----------------+
#
# +-------------+
# |unique_actors|
# +-------------+
# |       835513|
# +-------------+

# %% [markdown]
# ZADANIE2

# %% [markdown]
# INITIAL

# %%
from pyspark.sql.functions import udf, col, lit
from pyspark.sql.types import DoubleType

from pyspark.sql.functions import pandas_udf
from pyspark.sql.types import StringType
import pandas as pd

# %%
# Funkcja normalizująca ordering
def normalize_ordering(ordering, max_ordering):
    return ordering / max_ordering if max_ordering != 0 else 0

normalize_udf = udf(lambda x, max_val: normalize_ordering(x, max_val), DoubleType())
max_ordering = dataframe.agg({"ordering": "max"}).collect()[0][0]
df_normalized = dataframe.withColumn("ordering_normalized", normalize_udf(col("ordering"), lit(max_ordering)))
df_normalized.show()
# Out:
# +-------------+--------+------------+---------------+----------+--------------------+-------------------+
# |imdb_title_id|ordering|imdb_name_id|       category|       job|          characters|ordering_normalized|
# +-------------+--------+------------+---------------+----------+--------------------+-------------------+
# |    tt0000009|       1|   nm0063086|        actress|      NULL|[Miss Geraldine H...|                0.1|
# |    tt0000009|       2|   nm0183823|          actor|      NULL|      [Mr. Hamilton]|                0.2|
# |    tt0000009|       3|   nm1309758|          actor|      NULL|[Chauncey Depew -...|                0.3|
# |    tt0000009|       4|   nm0085156|       director|      NULL|                NULL|                0.4|
# |    tt0000574|       1|   nm0846887|        actress|      NULL|        [Kate Kelly]|                0.1|
# |    tt0000574|       2|   nm0846894|          actor|      NULL|     [School Master]|                0.2|
# |    tt0000574|       3|   nm3002376|          actor|      NULL|        [Steve Hart]|                0.3|
# |    tt0000574|       4|   nm0170118|        actress|      NULL|                NULL|                0.4|
# |    tt0000574|       5|   nm0846879|       director|      NULL|                NULL|                0.5|
# |    tt0000574|       6|   nm0317210|       producer|  producer|                NULL|                0.6|
# |    tt0000574|       7|   nm0425854|       producer|  producer|                NULL|                0.7|
# |    tt0000574|       8|   nm0846911|       producer|  producer|                NULL|                0.8|
# |    tt0000574|       9|   nm2421834|       composer|      NULL|                NULL|                0.9|
# |    tt0000574|      10|   nm0675239|cinematographer|      NULL|                NULL|                1.0|
# |    tt0001892|       1|   nm0003425|        actress|      NULL|            [Stella]|                0.1|
# |    tt0001892|       2|   nm0699637|          actor|      NULL|[Grev Johan Waldb...|                0.2|
# |    tt0001892|       3|   nm0375839|          actor|      NULL|[Hofjuveler A. Hi...|                0.3|
# |    tt0001892|       4|   nm0016799|          actor|      NULL|                NULL|                0.4|
# |    tt0001892|       5|   nm0300487|       director|      NULL|                NULL|                0.5|
# |    tt0001892|       6|   nm2131092|         writer|screenplay|                NULL|                0.6|
# +-------------+--------+------------+---------------+----------+--------------------+-------------------+
# only showing top 20 rows

# %%
# Funkcja czyszcząca stringi (usuwa znaki specjalne)
@pandas_udf(StringType())
def clean_category(col: pd.Series) -> pd.Series:
    return col.str.replace(r"[^a-zA-Z0-9 ]", "", regex=True)

df_cleaned = dataframe.withColumn("category_cleaned", clean_category(col("category")))
df_cleaned.show()
# Out:
# +-------------+--------+------------+---------------+----------+--------------------+----------------+
# |imdb_title_id|ordering|imdb_name_id|       category|       job|          characters|category_cleaned|
# +-------------+--------+------------+---------------+----------+--------------------+----------------+
# |    tt0000009|       1|   nm0063086|        actress|      NULL|[Miss Geraldine H...|         actress|
# |    tt0000009|       2|   nm0183823|          actor|      NULL|      [Mr. Hamilton]|           actor|
# |    tt0000009|       3|   nm1309758|          actor|      NULL|[Chauncey Depew -...|           actor|
# |    tt0000009|       4|   nm0085156|       director|      NULL|                NULL|        director|
# |    tt0000574|       1|   nm0846887|        actress|      NULL|        [Kate Kelly]|         actress|
# |    tt0000574|       2|   nm0846894|          actor|      NULL|     [School Master]|           actor|
# |    tt0000574|       3|   nm3002376|          actor|      NULL|        [Steve Hart]|           actor|
# |    tt0000574|       4|   nm0170118|        actress|      NULL|                NULL|         actress|
# |    tt0000574|       5|   nm0846879|       director|      NULL|                NULL|        director|
# |    tt0000574|       6|   nm0317210|       producer|  producer|                NULL|        producer|
# |    tt0000574|       7|   nm0425854|       producer|  producer|                NULL|        producer|
# |    tt0000574|       8|   nm0846911|       producer|  producer|                NULL|        producer|
# |    tt0000574|       9|   nm2421834|       composer|      NULL|                NULL|        composer|
# |    tt0000574|      10|   nm0675239|cinematographer|      NULL|                NULL| cinematographer|
# |    tt0001892|       1|   nm0003425|        actress|      NULL|            [Stella]|         actress|
# |    tt0001892|       2|   nm0699637|          actor|      NULL|[Grev Johan Waldb...|           actor|
# |    tt0001892|       3|   nm0375839|          actor|      NULL|[Hofjuveler A. Hi...|           actor|
# |    tt0001892|       4|   nm0016799|          actor|      NULL|                NULL|           actor|
# |    tt0001892|       5|   nm0300487|       director|      NULL|                NULL|        director|
# |    tt0001892|       6|   nm2131092|         writer|screenplay|                NULL|          writer|
# +-------------+--------+------------+---------------+----------+--------------------+----------------+
# only showing top 20 rows
